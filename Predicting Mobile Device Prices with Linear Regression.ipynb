# %% [markdown]
# #### Import the required libraries

# %%
import pandas as pd

# %% [markdown]
# #### Load the dataset

# %%
data = pd.read_csv("cleaned mobile data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  Rating ?/5  Number of Ratings  RAM  ROM/Storage  \
# 0           0         4.2              33561  2.0         32.0
# 1           1         4.2              77128  4.0         64.0
# 2           2         4.3              15175  4.0         64.0
# 3           3         4.2              22621  4.0         64.0
# 4           4         4.3              15175  4.0         64.0
#
#    Back/Rare Camera  Front Camera  Battery  Price in INR
# 0               144            26   5000.0          5649
# 1                99            31   5000.0         11999
# 2               145            26   5000.0          6999
# 3               118            26   5000.0          7749
# 4               145            26   5000.0          6999

# %% [markdown]
# #### Data PreProcessing

# %%
data.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
data
# Out:
#       Rating ?/5  Number of Ratings  RAM  ROM/Storage  Back/Rare Camera  \
# 0            4.2              33561  2.0         32.0               144
# 1            4.2              77128  4.0         64.0                99
# 2            4.3              15175  4.0         64.0               145
# 3            4.2              22621  4.0         64.0               118
# 4            4.3              15175  4.0         64.0               145
# ...          ...                ...  ...          ...               ...
# 1286         4.3              25582  4.0         64.0                69
# 1287         4.3              25582  4.0         64.0                69
# 1288         4.3              25582  4.0         64.0                69
# 1289         4.2               7117  8.0        128.0                77
# 1290         4.3              15701  4.0         64.0                50
#
#       Front Camera  Battery  Price in INR
# 0               26   5000.0          5649
# ...

# %%
data.columns
# Out:
# Index(['Rating ?/5', 'Number of Ratings', 'RAM', 'ROM/Storage',
#        'Back/Rare Camera', 'Front Camera', 'Battery', 'Price in INR'],
#       dtype='object')

# %%
# Separate the independent data (features)
X = data[['Rating ?/5', 'Number of Ratings', 'RAM', 'ROM/Storage',
       'Back/Rare Camera', 'Front Camera', 'Battery']]

# %%
X
# Out:
#       Rating ?/5  Number of Ratings  RAM  ROM/Storage  Back/Rare Camera  \
# 0            4.2              33561  2.0         32.0               144
# 1            4.2              77128  4.0         64.0                99
# 2            4.3              15175  4.0         64.0               145
# 3            4.2              22621  4.0         64.0               118
# 4            4.3              15175  4.0         64.0               145
# ...          ...                ...  ...          ...               ...
# 1286         4.3              25582  4.0         64.0                69
# 1287         4.3              25582  4.0         64.0                69
# 1288         4.3              25582  4.0         64.0                69
# 1289         4.2               7117  8.0        128.0                77
# 1290         4.3              15701  4.0         64.0                50
#
#       Front Camera  Battery
# 0               26   5000.0
# 1               31   5000.0
# ...

# %%
# Separate the target variable
y = data[['Price in INR']]

# %%
y
# Out:
#       Price in INR
# 0             5649
# 1            11999
# 2             6999
# 3             7749
# 4             6999
# ...            ...
# 1286         14999
# 1287         14999
# 1288         14999
# 1289         18999
# 1290         10999
#
# [1291 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
#(iv),(dv)

# %% [markdown]
# #### Train Test Split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,y,test_size=0.2)

# %%
(1291 /100) * 20
# Out:
# 258.2

# %%
xtrain.shape
# Out:
# (1032, 7)

# %%
xtest
# Out:
#       Rating ?/5  Number of Ratings  RAM  ROM/Storage  Back/Rare Camera  \
# 891          4.2              38416  6.0        128.0                15
# 681          4.4              26425  8.0        128.0               135
# 255          4.1               1238  4.0         64.0               119
# 482          4.1                859  4.0         64.0               113
# 1096         4.0              20231  6.0        128.0                12
# ...          ...                ...  ...          ...               ...
# 354          4.2              15053  6.0        128.0                99
# 428          4.1                916  3.0         32.0                65
# 410          4.6               1645  8.0        256.0                91
# 1243         4.3              79849  2.0         32.0               143
# 582          4.4              67861  4.0         64.0                29
#
#       Front Camera  Battery
# 891             12   5160.0
# 681             24   4200.0
# ...

# %%
ytest
# Out:
#       Price in INR
# 891          24999
# 681          31989
# 255          11199
# 482          14499
# 1096         18999
# ...            ...
# 354          14490
# 428           9990
# 410          79999
# 1243          7199
# 582          10990
#
# [259 rows x 1 columns]

# %% [markdown]
# training data ==>> (xtrain,ytrain) <br>
# testing data ==>> (xtest,ytest)

# %% [markdown]
# ### regression technique begins

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %% [markdown]
# #### training <br>
# .fit(trainingdata)

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %% [markdown]
# #### testing <br>
# .predict(testingdata)

# %%
ypred=lr.predict(xtest)

# %% [markdown]
# #### comparison <br>
# r2score from metrics library

# %%
from sklearn.metrics import r2_score
r2_score(ytest,ypred)
# Out:
# 0.47037331084259904

# %% [markdown]
# #### future planing

# %%
X
# Out:
#       Rating ?/5  Number of Ratings  RAM  ROM/Storage  Back/Rare Camera  \
# 0            4.2              33561  2.0         32.0               144
# 1            4.2              77128  4.0         64.0                99
# 2            4.3              15175  4.0         64.0               145
# 3            4.2              22621  4.0         64.0               118
# 4            4.3              15175  4.0         64.0               145
# ...          ...                ...  ...          ...               ...
# 1286         4.3              25582  4.0         64.0                69
# 1287         4.3              25582  4.0         64.0                69
# 1288         4.3              25582  4.0         64.0                69
# 1289         4.2               7117  8.0        128.0                77
# 1290         4.3              15701  4.0         64.0                50
#
#       Front Camera  Battery
# 0               26   5000.0
# 1               31   5000.0
# ...

# %%
X.columns
# Out:
# Index(['Rating ?/5', 'Number of Ratings', 'RAM', 'ROM/Storage',
#        'Back/Rare Camera', 'Front Camera', 'Battery'],
#       dtype='object')

# %% [markdown]
# #### Prediction

# %%
newmobileconfig = [[4.2,5800,6.0,64.0,115,26,5000]]

# %%
lr.predict(newmobileconfig)
# Out:
# C:\Users\thewa\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[9877.40753506]])

# %%
rating_out_5 = float(input("enter the rating out of 5 =>"))
Number_of_Ratings = float(input("enter the Number of Ratings =>"))
RAM = float(input("enter the RAM =>"))
ROM = float(input("enter the ROM"))
Back_camera = float(input("enter the Back_camera =>"))
Front_camera = float(input("enter the Front_camera =>"))
Battery = float(input("enter the Battery =>"))

newmobileconfig = [[rating_out_5,Number_of_Ratings,RAM,ROM,Back_camera,Front_camera,Battery]]
lr.predict(newmobileconfig)
# Out:
# enter the rating out of 5 =>4.5
# enter the Number of Ratings =>4900
# enter the RAM =>8
# enter the ROM256
# enter the Back_camera =>140
# enter the Front_camera =>52
# enter the Battery =>5000
# C:\Users\thewa\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[31252.87126801]])
